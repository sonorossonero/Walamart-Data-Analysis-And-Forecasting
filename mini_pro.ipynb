# %% [markdown]
# <a href="https://colab.research.google.com/github/LP606/-Walamart-Data-Analysis-And-Forecasting/blob/main/mini_pro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv("Walmart Data Analysis and Forcasting.csv")

# %%
data
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
data.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB

# %%
data['Date']
# Out:
# 0       05-02-2010
# 1       12-02-2010
# 2       19-02-2010
# 3       26-02-2010
# 4       05-03-2010
#            ...
# 6430    28-09-2012
# 6431    05-10-2012
# 6432    12-10-2012
# 6433    19-10-2012
# 6434    26-10-2012
# Name: Date, Length: 6435, dtype: object

# %%
data.describe()
# Out:
#              Store  Weekly_Sales  Holiday_Flag  Temperature   Fuel_Price  \
# count  6435.000000  6.435000e+03   6435.000000  6435.000000  6435.000000
# mean     23.000000  1.046965e+06      0.069930    60.663782     3.358607
# std      12.988182  5.643666e+05      0.255049    18.444933     0.459020
# min       1.000000  2.099862e+05      0.000000    -2.060000     2.472000
# 25%      12.000000  5.533501e+05      0.000000    47.460000     2.933000
# 50%      23.000000  9.607460e+05      0.000000    62.670000     3.445000
# 75%      34.000000  1.420159e+06      0.000000    74.940000     3.735000
# max      45.000000  3.818686e+06      1.000000   100.140000     4.468000
#
#                CPI  Unemployment
# count  6435.000000   6435.000000
# mean    171.578394      7.999151
# std      39.356712      1.875885
# min     126.064000      3.879000
# 25%     131.735000      6.891000
# 50%     182.616521      7.874000
# 75%     212.743293      8.622000
# max     227.232807     14.313000

# %%
data.isnull().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %%
data.nunique()
# Out:
# Store             45
# Date             143
# Weekly_Sales    6435
# Holiday_Flag       2
# Temperature     3528
# Fuel_Price       892
# CPI             2145
# Unemployment     349
# dtype: int64

# %%
data.duplicated().any() #checking duplicate val
# Out:
# False

# %%
data['Store'].value_counts() #count of values
# Out:
# 1     143
# 24    143
# 26    143
# 27    143
# 28    143
# 29    143
# 30    143
# 31    143
# 32    143
# 33    143
# 34    143
# 35    143
# 36    143
# 37    143
# 38    143
# 39    143
# 40    143
# 41    143
# 42    143
# 43    143
# 44    143
# 25    143
# 23    143
# 2     143
# 22    143
# 3     143
# 4     143
# 5     143
# 6     143
# 7     143
# 8     143
# 9     143
# 10    143
# 11    143
# 12    143
# 13    143
# 14    143
# 15    143
# 16    143
# 17    143
# 18    143
# 19    143
# 20    143
# 21    143
# 45    143
# Name: Store, dtype: int64

# %%
data['Date'].value_counts()
# Out:
# 05-02-2010    45
# 23-12-2011    45
# 11-11-2011    45
# 18-11-2011    45
# 25-11-2011    45
#               ..
# 07-01-2011    45
# 14-01-2011    45
# 21-01-2011    45
# 28-01-2011    45
# 26-10-2012    45
# Name: Date, Length: 143, dtype: int64

# %%
data['Weekly_Sales'].value_counts()
# Out:
# 1643690.90    1
# 446751.45     1
# 1332261.01    1
# 1366193.35    1
# 1384870.51    1
#              ..
# 551799.63     1
# 573498.64     1
# 553901.97     1
# 533161.64     1
# 760281.43     1
# Name: Weekly_Sales, Length: 6435, dtype: int64

# %%
data['Holiday_Flag'].value_counts()
# Out:
# 0    5985
# 1     450
# Name: Holiday_Flag, dtype: int64

# %%
data['Temperature'].value_counts()
# Out:
# 50.43    11
# 67.87    10
# 76.67     9
# 76.03     9
# 70.28     9
#          ..
# 34.93     1
# 38.53     1
# 41.10     1
# 45.54     1
# 74.09     1
# Name: Temperature, Length: 3528, dtype: int64

# %%
data['Fuel_Price'].value_counts()
# Out:
# 3.638    39
# 3.630    34
# 2.771    29
# 3.891    29
# 3.524    28
#          ..
# 2.863     1
# 2.995     1
# 3.053     1
# 3.448     1
# 3.576     1
# Name: Fuel_Price, Length: 892, dtype: int64

# %%
data['CPI'].value_counts()
# Out:
# 130.550207    11
# 129.043200    11
# 127.580032    11
# 127.440484    11
# 127.300935    11
#               ..
# 214.751084     1
# 214.815521     1
# 214.961638     1
# 215.107755     1
# 214.741539     1
# Name: CPI, Length: 2145, dtype: int64

# %%
data['Unemployment'].value_counts()
# Out:
# 8.099    78
# 8.163    56
# 7.852    56
# 8.200    52
# 6.565    52
#          ..
# 7.138     4
# 8.665     4
# 8.000     4
# 9.151     4
# 5.217     4
# Name: Unemployment, Length: 349, dtype: int64

# %% [markdown]
#  Find the above statistics of the value counts for each column

# %%
data.hist(figsize=(15,8),bins= 20)
# Out:
# array([[<Axes: title={'center': 'Store'}>,
#         <Axes: title={'center': 'Weekly_Sales'}>,
#         <Axes: title={'center': 'Holiday_Flag'}>],
#        [<Axes: title={'center': 'Temperature'}>,
#         <Axes: title={'center': 'Fuel_Price'}>,
#         <Axes: title={'center': 'CPI'}>],
#        [<Axes: title={'center': 'Unemployment'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
plt.pie(data['Holiday_Flag'].value_counts() , labels=list(data['Holiday_Flag'].value_counts().index) , startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x7be74337a3b0>,
# ...
#  [Text(-0.2397217412454327, -1.073561123911563, '0'),
#   Text(0.23972176637394413, 1.0735611183004703, '1')])

# %%
sns.barplot(x=data['Holiday_Flag'] , y = data['Weekly_Sales'])
# Out:
# <Axes: xlabel='Holiday_Flag', ylabel='Weekly_Sales'>

# %% [markdown]
# It shows that in Holiday Weeks , the Weekly Sales is higher compared to Non Holiday Weeks

# %% [markdown]
# Exploratory Data Analysis

# %% [markdown]
# Which store has the Maximum and Minimum weekly sales?

# %%
df1 = data.groupby('Store')['Weekly_Sales'].agg(['sum'])
df1_Max_Min = df1.sort_values(by = 'sum' ,ascending=False).reset_index()

# %%
## Top 10 Stores having the maximum weekly sales
df1_top10 = df1_Max_Min.head(10)

# %%
df1_top10
# Out:
#    Store           sum
# 0     20  3.013978e+08
# 1      4  2.995440e+08
# 2     14  2.889999e+08
# 3     13  2.865177e+08
# 4      2  2.753824e+08
# 5     10  2.716177e+08
# 6     27  2.538559e+08
# 7      6  2.237561e+08
# 8      1  2.224028e+08
# 9     39  2.074455e+08

# %%
## Bottom 10 Stores having the least weekly stores
df1_Max_Min.tail(10)
# Out:
#     Store          sum
# 35     29  77141554.31
# 36     16  74252425.40
# 37     37  74202740.32
# 38     30  62716885.12
# 39      3  57586735.07
# 40     38  55159626.42
# 41     36  53412214.97
# 42      5  45475688.90
# 43     44  43293087.84
# 44     33  37160221.96

# %% [markdown]
# Weekly Sales Vs. UnEmployement Rate

# %%
plt.bar(data['Unemployment'].unique(),data.groupby('Unemployment')['Weekly_Sales'].sum(),color = 'green')
plt.title("Weekly Sales vs. Unemployement Rate")
plt.xlabel("Unemployment Rate")
plt.ylabel("Weekly Sales")
# Out:
# Text(0, 0.5, 'Weekly Sales')

# %% [markdown]
# it has been noticed that when Unemployment rate is around 9 there is more weekly sales

# %%
plt.scatter(data['Unemployment'],data['Weekly_Sales'],edgecolors='black')
plt.title('Weekly Sales vs. Unemployement Rate')
plt.xlabel('Unemployment Rate')
plt.ylabel('Weekly Sales')
# Out:
# Text(0, 0.5, 'Weekly Sales')

# %% [markdown]
# the above comparision shows that when unemployment rate exceeds 10 the weekly sales drops
#
# Weekly Sales Vs. Tempreture

# %%
plt.scatter(data['Temperature'].unique(),data.groupby('Temperature')['Weekly_Sales'].sum())
plt.title("Temperature vs Weekly Sales")
plt.xlabel("Tempreature")
plt.ylabel("Weekly Sales")
# Out:
# Text(0, 0.5, 'Weekly Sales')

# %% [markdown]
# it has been oberved that below 20 tempreture there are having the minimum weekly sales.
#
# Weekly Sales Vs. Holiday_Flag

# %%
sns.barplot(data=data , x='Holiday_Flag' , y='Weekly_Sales')
plt.title("Holiday Flag vs Weekly Sales")
# Out:
# Text(0.5, 1.0, 'Holiday Flag vs Weekly Sales')

# %% [markdown]
# it seems that the weekly sales is more in Holiday weeks compared to Non Holiday Weeks

# %% [markdown]
# Weekly Sales vs Fuel Price

# %%
plt.title("Weekly Sales vs Fuel Price")
plt.xlabel("Fuel Price")
plt.ylabel("Weekly Sales")
plt.scatter(data['Fuel_Price'] , data['Weekly_Sales'],color = 'red' , edgecolors='black')

# %% [markdown]
# it has been observed that the sales are getting lower when the fuel price is above 4 USD.

# %% [markdown]
# Weekly Sales vs CPI

# %%
plt.scatter(data['CPI'],data['Weekly_Sales'],color = 'green' , edgecolors='black')
plt.title("Weekly Sales vs CPI")
plt.xlabel("Weekly Sales")
plt.ylabel('CPI')
# Out:
# Text(0, 0.5, 'CPI')

# %% [markdown]
# its been observed that between CPI 140 to 180 there are having absolutely low weekly sales

# %% [markdown]
# We will find the store wise yearly sales report

# %%
data['Year'] = pd.to_datetime(data['Date'])
data['Year'] = data['Year'].dt.year
# Out:
# <ipython-input-83-eb04f9eedc51>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   data['Year'] = pd.to_datetime(data['Date'])

# %%
data.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment  Year
# 0  211.096358         8.106  2010
# 1  211.242170         8.106  2010
# 2  211.289143         8.106  2010
# 3  211.319643         8.106  2010
# 4  211.350143         8.106  2010

# %%
year_wise_sales = data.groupby(['Store' , 'Year'])['Weekly_Sales'].sum()

# %%
year_wise_sales
# Out:
# Store  Year
# 1      2010    73278832.00
#        2011    80921918.83
#        2012    68202058.02
# 2      2010    95277864.19
#        2011    98607881.42
#                   ...
# 44     2011    15498194.67
#        2012    14187373.72
# 45     2010    38536343.37
#        2011    41135367.88
#        2012    32723630.17
# Name: Weekly_Sales, Length: 135, dtype: float64

# %% [markdown]
# Comparision of Total Sales each store wise and year wise

# %% [markdown]
# Total Sales Data Yearly Wise

# %%
avg_sales_2010 = data['Weekly_Sales'][data.Year==2010].groupby(data['Store']).mean()
avg_sales_2011 = data['Weekly_Sales'][data.Year==2011].groupby(data['Store']).mean()
avg_sales_2012 = data['Weekly_Sales'][data.Year==2012].groupby(data['Store']).mean()
plt.figure(figsize=(20,8))
sns.lineplot(x=avg_sales_2010.index ,y=avg_sales_2010.values)
sns.lineplot(x=avg_sales_2011.index ,y=avg_sales_2011.values)
sns.lineplot(x=avg_sales_2012.index ,y=avg_sales_2012.values)
plt.grid()
plt.xticks(np.arange(1,45,step=1))
plt.legend(['2010','2011','2012'],loc = 'best' , fontsize=16)
plt.title("Yearly Average Sales Data " , fontsize=18)
plt.xlabel("Store" , fontsize=16)
plt.ylabel('Average Sales' , fontsize=16)
plt.show()

# %% [markdown]
# Total Sales Data Combined Years 2010 , 2011 ,2012 - Store Wise

# %%
Total_sales = data['Weekly_Sales'].groupby(data['Store']).sum()
plt.figure(figsize=(20,8))
sns.barplot(x=Total_sales.index,y=Total_sales.values,palette='dark')
plt.title("Total Sales Data  - Store Wise" ,fontsize = 18)
plt.xlabel('Store' , fontsize=16)
plt.ylabel('Total Sales',fontsize=16)
# Out:
# Text(0, 0.5, 'Total Sales')

# %% [markdown]
# It has been observed that Store 4&20 has maximum sales and 33&44 has minimum in the Total period

# %% [markdown]
# Lets Find Average Sales Combined 2010,2011&2012

# %%
avg_sales = data['Weekly_Sales'].groupby(data['Store']).mean()
plt.figure(figsize=(20,8))
sns.barplot(x=avg_sales.index ,y=avg_sales.values , palette='dark')
plt.title("Average Sales Data - Store Wise" , fontsize=18)
plt.xlabel("Store" , fontsize=16)
plt.ylabel("Average Sales",fontsize=16)
# Out:
# Text(0, 0.5, 'Average Sales')

# %% [markdown]
# It has been Observed that Store 4&20 has the maximum average sales and 33&44 has the minimum average sales in the period

# %% [markdown]
# Feature Selection¶

# %% [markdown]
# We will do first train, test split then will build a co-relation between Independent and Dependent Features

# %%
data.drop(columns=['Date'], inplace=True)

# %%
from sklearn.model_selection import train_test_split
x = data.drop('Weekly_Sales',axis=1)
y = data['Weekly_Sales']
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=0)

# %%
plt.figure(figsize=(12,10))
cor = x_train.corr()
sns.heatmap(data=cor,annot=True,cmap=plt.cm.CMRmap_r)
plt.title("Coorelation Matrix")
plt.show()

# %% [markdown]
# if we consider the threshold is 85% or above , Then No Columns are required to drop because no columns are highly corelated with each other.

# %% [markdown]
# **Machine Learning**

# %% [markdown]
# Linear Regression

# %%
numeric_float = float(numeric_value)

# %%
from sklearn.linear_model import LinearRegression
lr_regressor = LinearRegression(fit_intercept=True)
lr_regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Evaluating The Accuracy of the model through below

# %% [markdown]
# R2_Score

# %%
from sklearn.metrics import r2_score
y_pred_lr = lr_regressor.predict(x_test)
r2_score(y_test,y_pred_lr)
# Out:
# 0.15788886506050825

# %% [markdown]
# The Accuracy of Linear Regression Algorithm output is 16%

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
rf_regressor = RandomForestRegressor(n_estimators=100 , random_state=42)
rf_regressor.fit(x_train,y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred_rf = rf_regressor.predict(x_test)

# %%
r2_score(y_test , y_pred_rf)
# Out:
# 0.9292868115524832

# %%
res = pd.DataFrame(y_pred_rf) ##Saving the result in a Data Frame
res.index = x_test.index
res.columns = ['prediction']
res.to_csv(r"E:\ML Projects\Walmart Project_Anshuman\prediction_results.csv")

# %% [markdown]
# The Accuracy of Random Forest Algorithm output is 93%

# %% [markdown]
# Ridge Regression

# %%
from sklearn.linear_model import Ridge
ri_regressor = Ridge(fit_intercept=False ,random_state=42)
ri_regressor.fit(x_train,y_train)
# Out:
# Ridge(fit_intercept=False, random_state=42)

# %%
from sklearn.metrics import r2_score
y_pred = ri_regressor.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.162254683347532

# %% [markdown]
# The Accuracy of Linear Regression Algorithm output is 16%
